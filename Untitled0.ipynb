# %% [markdown]
# <a href="https://colab.research.google.com/github/lankevamsikiran/wcount/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = input('Enter first number: ')
num2 = input('Enter second number: ')
# Add two numbers
sum = float(num1) + float(num2)
# Display the sum
print('The sum of {0} and {1} is {2}'.format(num1, num2, sum))
# Out:
# Enter first number: 10
# Enter second number: 50
# The sum of 10 and 50 is 60.0
